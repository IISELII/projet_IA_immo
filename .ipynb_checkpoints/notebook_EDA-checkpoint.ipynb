# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Imports de mes librairies

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import de mes données

# %%
data = pd.read_csv("data/train_data.csv")

# %%
# j'affiche mon dataframe
data
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %% [markdown]
# ## Informations basiques à propos de mon dataframe

# %%
# I want to know basic information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16512 entries, 0 to 16511
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          16512 non-null  int64
#  1   longitude           16512 non-null  float64
#  2   latitude            16512 non-null  float64
#  3   housing_median_age  16512 non-null  float64
#  4   total_rooms         16512 non-null  float64
#  5   total_bedrooms      16336 non-null  float64
#  6   population          16512 non-null  float64
#  7   households          16512 non-null  float64
#  8   median_income       16512 non-null  float64
#  9   median_house_value  16512 non-null  float64
#  10  ocean_proximity     16512 non-null  object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 1.4+ MB

# %%
# i want to have basics stats about the dataset
data.describe()
# Out:
#          Unnamed: 0     longitude      latitude  housing_median_age  \
# count  16512.000000  16512.000000  16512.000000        16512.000000
# mean   10295.498789   -119.564046     35.626523           28.624516
# std     5941.973488      2.005033      2.139150           12.597980
# min        0.000000   -124.350000     32.540000            1.000000
# 25%     5178.750000   -121.790000     33.930000           18.000000
# 50%    10263.500000   -118.490000     34.250000           29.000000
# 75%    15438.250000   -118.010000     37.710000           37.000000
# max    20639.000000   -114.310000     41.950000           52.000000
#
#         total_rooms  total_bedrooms    population    households  \
# count  16512.000000    16336.000000  16512.000000  16512.000000
# mean    2644.170603      539.319540   1435.017260    501.135962
# std     2213.946369      425.207704   1158.151967    385.650673
# min        6.000000        2.000000      3.000000      2.000000
# ...

# %% [markdown]
# ## Duplicate values

# %%
# .duplicated will show the number of duplicate values if they are present in the data

# find the duplicates 

data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# J'en conclue que je n'ai pas de duplicates dans mon dataframe

# %% [markdown]
# ## Unique values in the data

# %%
# I want to see the number of unique value in the particular column

data["ocean_proximity"].unique()
# Out:
# array(['INLAND', '<1H OCEAN', 'NEAR OCEAN', 'NEAR BAY', 'ISLAND'],
#       dtype=object)

# %%
# the other column have too much unique values and it's not very useful to show them

# %% [markdown]
# ## Visualize the Unique counts

# %%
# Now I want to know ho< much time these unique values are in the dataset
# sns.countplot(data['ocean_proximity']).unique()

# %% [markdown]
# ## Find the Null values

# %%
# Find Null Values

missing_values_count = data.isnull().sum()
missing_values_count
# Out:
# Unnamed: 0              0
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        176
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# percent of data that is missing 

total_cells = np.product(data.shape)
total_missing = missing_values_count.sum()


percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.09689922480620156

# %% [markdown]
# ## Replace the Null values

# %%
# I decided to drop the 176 rows with NaN
# It represent only 0.09 % of my data, it'll not have a great consequence for my prediction model

data_1 = data.dropna()
data_1
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
# I check if all my Nan are drop

data_1.isnull().sum()
# Out:
# Unnamed: 0            0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# ## Know the datatypes

# %%
# knowing the datatypes wich I am exploring is very important and an easy process too. So do it. 

data_1.dtypes
# Out:
# Unnamed: 0              int64
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %% [markdown]
# ## detect outliers

# %%
data_1
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
# 1
sns.boxplot(data_1["longitude"])
# Out:
# /home/selmane/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='longitude'>

# %%
#2
sns.boxplot(data_1["latitude"])
# Out:
# /home/selmane/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='latitude'>

# %%
#3
sns.boxplot(data_1["housing_median_age"])
# Out:
# /home/selmane/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='housing_median_age'>

# %%
#4
sns.boxplot(data_1["total_rooms"])
# Out:
# /home/selmane/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_rooms'>

# %%
# je drop les rows ou il y'a des outliers sur cette colonne 
data_1_1 = data_1.loc[data_1["total_rooms"] <6000]
data_1_1
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
#5
sns.boxplot(data_1_1["total_bedrooms"])
# Out:
# /home/selmane/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bedrooms'>

# %%
# je drop les rows ou il y'a des outliers sur cette colonne 
data_1_2 = data_1_1.loc[data_1_1["total_bedrooms"] <1100]
data_1_2
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16510        6637    -118.14     34.16                39.0       2776.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
#6

sns.boxplot(data_1_2["population"])
# Out:
# /home/selmane/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='population'>

# %%
# je drop les rows ou il y'a des outliers sur cette colonne 
data_1_3 = data_1_2.loc[data_1_2["population"] <2500]
data_1_3
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16506       14696    -117.09     32.79                36.0       1529.0
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
#7
sns.boxplot(data_1_3["households"])
# Out:
# /home/selmane/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='households'>

# %%
# je drop les rows ou il y'a des outliers sur cette colonne 
data_1_4 = data_1_3.loc[data_1_3["households"] <900]
data_1_4
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16506       14696    -117.09     32.79                36.0       1529.0
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
#8
sns.boxplot(data_1_4["median_income"])
# Out:
# /home/selmane/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='median_income'>

# %%
# je drop les rows ou il y'a des outliers sur cette colonne 
data_1_5 = data_1_4.loc[data_1_4["median_income"] <8]
data_1_5
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16506       14696    -117.09     32.79                36.0       1529.0
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
#9 

sns.boxplot(data_1_5["median_house_value"])
# Out:
# /home/selmane/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='median_house_value'>

# %%
# je drop les rows ou il y'a des outliers sur cette colonne 
data_1_6 = data_1_5.loc[data_1_5["median_house_value"] <460000]
data_1_6
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16506       14696    -117.09     32.79                36.0       1529.0
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %%
# mon dataframe sans les outliers

data_2 = data_1_6
data_2
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0            2072    -119.84     36.77                 6.0       1853.0
# 1           10600    -117.80     33.68                 8.0       2032.0
# 2            2494    -120.19     36.60                25.0        875.0
# 3            4284    -118.32     34.10                31.0        622.0
# 4           16541    -121.23     37.79                21.0       1922.0
# ...           ...        ...       ...                 ...          ...
# 16506       14696    -117.09     32.79                36.0       1529.0
# 16507        1099    -121.90     39.59                20.0       1465.0
# 16508       18898    -122.25     38.11                49.0       2365.0
# 16509       11798    -121.22     38.92                19.0       2531.0
# 16511        2575    -124.13     40.80                31.0       2152.0
#
#        total_bedrooms  population  households  median_income  \
# ...

# %% [markdown]
# ## Correlation Plot

# %% [markdown]
# Finally, to find the correlation among the variables, I can make use of the correlation function. This will give me a fair idea of the correlation strength between different variables.

# %%
# This is the correlation matrix with the range from +1 to -1 where +1 is highly and positively correlated 
# and -1 will be highly negatively correlated.

# %%
data_2.corr()
# Out:
#                     Unnamed: 0  longitude  latitude  housing_median_age  \
# Unnamed: 0            1.000000  -0.092534  0.064367           -0.196000
# longitude            -0.092534   1.000000 -0.922239           -0.087380
# latitude              0.064367  -0.922239  1.000000           -0.016973
# housing_median_age   -0.196000  -0.087380 -0.016973            1.000000
# total_rooms           0.101934  -0.013779  0.017267           -0.275761
# total_bedrooms        0.057251   0.026139 -0.034968           -0.209985
# population            0.037421   0.108928 -0.137914           -0.167445
# households            0.062534   0.023617 -0.058861           -0.175157
# median_income         0.091408  -0.004467 -0.090344           -0.168261
# median_house_value    0.090195  -0.037401 -0.165920            0.094410
#
#                     total_rooms  total_bedrooms  population  households  \
# Unnamed: 0             0.101934        0.057251    0.037421    0.062534
# ...

# %%
# visualize correlation matrix with seaborn

# %%
# correlation plot 

sns.heatmap(data_2.corr())
# Out:
# <AxesSubplot:>
